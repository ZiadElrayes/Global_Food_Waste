# %% [markdown]
# # 🌍 Global Food Wastage

# %% [markdown]
# 1 -1️⃣ Global & Regional Trends
# - How has food waste changed from 2018 to 2024 across different regions?
# - Which countries are experiencing the highest increase or decrease in food waste?
#
# 2 -2️⃣ Food Type Analysis
# - Which food categories contribute the most to wastage? (e.g., dairy, grains, meat, vegetables)
# - Seasonal patterns: Are there specific times of the year when certain foods are wasted more?
#
# 3 -3️⃣ Economic Impact
# - Total economic loss due to food wastage per country.
# - Which food categories contribute the most to financial loss?
# - How does food wastage correlate with economic status (developed vs. developing nations)?
#
# 4 -4️⃣ Per Capita Waste Insights
# - Which countries have the highest and lowest per capita food waste?
# - Are high-income countries wasting more per capita than low-income ones?
#
# 5 -5️⃣ Predictive Analytics
# - Future food wastage trends based on past data.
# - Can machine learning models predict which countries or food categories will have the most wastage in the future?
#
# 6 -6️⃣ Sustainability & Policy Impact
# - Are countries with strict food waste policies seeing a decline in waste?
# - What sustainability practices have led to a reduction in food wastage?
#
# 7 -7️⃣ Industry-Specific Insights
# - Which industries (restaurants, retail, households) contribute most to food waste?
# - What measures can businesses take to optimize food supply chains and reduce waste?

# %% [markdown]
# ## Data Pre-Processing

# %%
# %pip install seaborn

# %%
## Libraies in use
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
## Calling Data
gfw = pd.read_csv('global_food_wastage_dataset.csv')
gfw.head()
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 0  Australia  2019  Fruits & Vegetables            19268.63
# 1  Indonesia  2019        Prepared Food             3916.97
# 2    Germany  2022       Dairy Products             9700.16
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
#
#    Economic Loss (Million $)  Avg Waste per Capita (Kg)  Population (Million)  \
# 0                   18686.68                      72.69                 87.59
# 1                    4394.48                     192.52               1153.99
# 2                    8909.16                     166.94               1006.11
# 3                   40551.22                     120.19                953.05
# 4                   36980.82                     104.74               1105.47
#
#    Household Waste (%)
# 0                53.64
# 1                30.61
# 2                48.08
# 3                31.91
# ...

# %%
## Data Information 
gfw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    5000 non-null   object
#  1   Year                       5000 non-null   int64
#  2   Food Category              5000 non-null   object
#  3   Total Waste (Tons)         5000 non-null   float64
#  4   Economic Loss (Million $)  5000 non-null   float64
#  5   Avg Waste per Capita (Kg)  5000 non-null   float64
#  6   Population (Million)       5000 non-null   float64
#  7   Household Waste (%)        5000 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 273.5+ KB

# %%
## Data Describe
gfw.describe()
# Out:
#               Year  Total Waste (Tons)  Economic Loss (Million $)  \
# count  5000.000000         5000.000000                5000.000000
# mean   2021.015600        25061.780072               25039.703870
# std       1.999239        14245.119588               14620.236429
# min    2018.000000          502.610000                 406.690000
# 25%    2019.000000        12783.737500               12612.477500
# 50%    2021.000000        24865.220000               24428.155000
# 75%    2023.000000        37471.035000               37146.037500
# max    2024.000000        49990.760000               59228.930000
#
#        Avg Waste per Capita (Kg)  Population (Million)  Household Waste (%)
# count                 5000.00000           5000.000000          5000.000000
# mean                   109.46397            706.606416            50.060890
# std                     51.93373            402.546464            11.596203
# ...

# %%
## Checking number of nulls 
gfw.isna().sum()
# Out:
# Country                      0
# Year                         0
# Food Category                0
# Total Waste (Tons)           0
# Economic Loss (Million $)    0
# Avg Waste per Capita (Kg)    0
# Population (Million)         0
# Household Waste (%)          0
# dtype: int64

# %%
## Data Column names 
gfw.columns
# Out:
# Index(['Country', 'Year', 'Food Category', 'Total Waste (Tons)',
#        'Economic Loss (Million $)', 'Avg Waste per Capita (Kg)',
#        'Population (Million)', 'Household Waste (%)'],
#       dtype='object')

# %% [markdown]
# 1️⃣ Country
#
# 📌 Definition: The name of the country where the food wastage data was recorded.
#
# 🔍 Insight: Helps identify which countries have the highest or lowest food waste levels.
#
# 2️⃣ Year
#
# 📌 Definition: The year in which the food wastage data was collected (ranging from 2018 to 2024).
#
# 🔍 Insight: Allows for trend analysis to see how food waste has evolved over time.
#
# 3️⃣ Food Category
#
# 📌 Definition: The type of food that was wasted (e.g., fruits, vegetables, dairy, meat, grains).
#
# 🔍 Insight: Helps determine which food categories contribute the most to overall wastage.
#
# 4️⃣ Total Waste (Tons)
#
# 📌 Definition: The total amount of food wasted in a country for a given year, measured in metric tons.
#
# 🔍 Insight: Provides an understanding of the scale of food wastage in absolute terms.
#
# 5️⃣ Economic Loss (Million $)
#
# 📌 Definition: The estimated financial loss due to food wastage, measured in millions of U.S. dollars.
#
# 🔍 Insight: Shows the financial impact of food waste on a country’s economy.
#
# 6️⃣ Avg Waste per Capita (Kg)
#
# 📌 Definition: The average amount of food wasted per person in a country, measured in kilograms.
#
# 🔍 Insight: Highlights how much food is wasted on an individual level, useful for comparisons across countries.
#
# 7️⃣ Population (Million)
#
# 📌 Definition: The total population of the country in the given year, measured in millions.
#
# 🔍 Insight: Helps normalize waste data and analyze per capita trends.
#
# 8️⃣ Household Waste (%)
#
# 📌 Definition: The percentage of total food waste that comes from households (as opposed to retail, restaurants, or farms).

# %%
sns.pairplot(gfw, hue = 'Year')

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Questions that needs to be answered

# %% [markdown]
# #### 1 ) How has food wastage evolved across different regions from 2018 to 2024?

# %%
gfw[['Country' , 'Year' , 'Total Waste (Tons)']]
# Out:
#         Country  Year  Total Waste (Tons)
# 0     Australia  2019            19268.63
# 1     Indonesia  2019             3916.97
# 2       Germany  2022             9700.16
# 3        France  2023            46299.69
# 4        France  2023            33096.57
# ...         ...   ...                 ...
# 4995     France  2021            47524.74
# 4996  Australia  2021            32337.72
# 4997      China  2018            20640.96
# 4998  Australia  2021            26566.64
# 4999     France  2024             8860.27
#
# [5000 rows x 3 columns]

# %%
gfw['Year'].value_counts()
# Out:
# Year
# 2023    737
# 2021    734
# 2020    731
# 2024    721
# 2018    708
# 2019    691
# 2022    678
# Name: count, dtype: int64

# %%
print(sum(gfw['Total Waste (Tons)']) , "Tons of Food wasted from 2018 till 2024 ")
# Out:
# 125308900.36 Tons of Food wasted from 2018 till 2024

# %%
gfw['Country'].value_counts()
# Out:
# Country
# Germany         287
# Spain           274
# China           262
# Brazil          258
# USA             257
# India           257
# Turkey          256
# Canada          254
# Italy           253
# Mexico          251
# South Africa    245
# Indonesia       244
# UK              242
# South Korea     241
# Japan           240
# Saudi Arabia    239
# France          239
# Argentina       238
# Russia          237
# Australia       226
# Name: count, dtype: int64

# %%
twof = gfw.groupby("Year")['Total Waste (Tons)'].sum()
twof
# Out:
# Year
# 2018    17625290.55
# 2019    17527936.61
# 2020    18128400.36
# 2021    18305242.89
# 2022    17107497.90
# 2023    18444672.83
# 2024    18169859.22
# Name: Total Waste (Tons), dtype: float64

# %%
sns.displot(data = gfw , x = 'Total Waste (Tons)', hue = 'Year', multiple = "stack" , kind = 'kde')

# %% [markdown]
# #### 2 ) Which countries have the highest and lowest food wastage levels?

# %%
country_tw = gfw.groupby('Country')['Total Waste (Tons)'].sum().sort_values(ascending = False)
country_tw
# Out:
# Country
# Turkey          6879885.81
# Canada          6790678.49
# Spain           6790574.25
# Germany         6760053.01
# Mexico          6589169.52
# USA             6446334.63
# China           6411096.18
# Brazil          6391752.50
# France          6334495.00
# Indonesia       6294447.74
# India           6245313.77
# Italy           6207707.28
# Argentina       6082367.52
# South Africa    6056470.30
# Saudi Arabia    5983283.87
# Japan           5907491.06
# Australia       5887361.29
# Russia          5832689.46
# UK              5808621.61
# South Korea     5609107.07
# Name: Total Waste (Tons), dtype: float64

# %%
# Group by Year and Country, then sum the Total Waste (Tons)
yearly_waste = gfw.groupby(["Year", "Country"])["Total Waste (Tons)"].sum().reset_index()

# Find the country with the maximum waste for each year
most_wasting_countries = yearly_waste.loc[yearly_waste.groupby("Year")["Total Waste (Tons)"].idxmax()]

# Display the results
print(most_wasting_countries)
# Out:
#      Year Country  Total Waste (Tons)
# 7    2018   India          1198140.19
# 23   2019  Canada          1152692.58
# 57   2020  Turkey          1131072.90
# 63   2021  Canada          1208957.19
# 99   2022     USA          1240270.48
# 109  2023   Italy          1344485.26
# 131  2024  Mexico          1140293.74

# %%
colors = sns.color_palette("husl", len(country_tw))
plt.figure(figsize = (25, 6))
plt.bar(country_tw.index , country_tw.values , color = colors)
plt.xlabel("Country")
plt.ylabel("Total Waste of food in Tons")
plt.title("Total waste of Food in Tons for each Country through the years from 2018 - 2024")
# Out:
# Text(0.5, 1.0, 'Total waste of Food in Tons for each Country through the years from 2018 - 2024')

# %% [markdown]
# #### 3 ) Are there any specific regions where food wastage is rising at an alarming rate?

# %% [markdown]
# #### 4 ) Which types of food are wasted the most globally?

# %%
gfw.head()
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 0  Australia  2019  Fruits & Vegetables            19268.63
# 1  Indonesia  2019        Prepared Food             3916.97
# 2    Germany  2022       Dairy Products             9700.16
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
#
#    Economic Loss (Million $)  Avg Waste per Capita (Kg)  Population (Million)  \
# 0                   18686.68                      72.69                 87.59
# 1                    4394.48                     192.52               1153.99
# 2                    8909.16                     166.94               1006.11
# 3                   40551.22                     120.19                953.05
# 4                   36980.82                     104.74               1105.47
#
#    Household Waste (%)
# 0                53.64
# 1                30.61
# 2                48.08
# 3                31.91
# ...

# %%
FC = gfw['Food Category'].value_counts()
FC
# Out:
# Food Category
# Prepared Food          711
# Beverages              639
# Bakery Items           630
# Fruits & Vegetables    620
# Dairy Products         616
# Meat & Seafood         605
# Frozen Food            596
# Grains & Cereals       583
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15,6))
plt.bar(FC.index , FC.values , color = colors)
plt.xlabel("Food Category")
plt.ylabel("Total")
plt.title("Total wasted food Type")
# Out:
# Text(0.5, 1.0, 'Total wasted food Type')

# %% [markdown]
# #### 5 ) Are there any seasonal trends in food wastage for specific food categories?

# %%
gfw_2018 = gfw[gfw.Year == 2018]
gfw_2018.head()
# Out:
#     Country  Year   Food Category  Total Waste (Tons)  \
# 13   France  2018       Beverages            29295.07
# 19    China  2018   Prepared Food            11314.08
# 25  Germany  2018       Beverages            12336.20
# 27   France  2018     Frozen Food            17470.52
# 29   Mexico  2018  Meat & Seafood            20604.34
#
#     Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 13                   34102.25                      46.64
# 19                   10287.70                     111.67
# 25                   10077.91                      38.86
# 27                   16267.24                      73.76
# 29                   23257.47                      31.88
#
#     Population (Million)  Household Waste (%)
# 13               1286.73                32.95
# 19                953.52                33.75
# 25                689.21                36.92
# 27                855.40                60.11
# 29                412.45                67.53

# %%
gfw_2020 = gfw[gfw.Year == 2020]
gfw_2020.head()
# Out:
#          Country  Year        Food Category  Total Waste (Tons)  \
# 17  Saudi Arabia  2020        Prepared Food            18483.82
# 21     Australia  2020  Fruits & Vegetables             1322.82
# 30     Argentina  2020         Bakery Items            49310.46
# 39         Japan  2020            Beverages            44797.11
# 41        Russia  2020       Dairy Products            13679.64
#
#     Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 17                   21071.65                     198.62
# 21                    1394.01                      88.85
# 30                   49520.57                      21.69
# 39                   41233.80                      64.74
# 41                   14249.79                     182.75
#
#     Population (Million)  Household Waste (%)
# 17                143.12                48.83
# 21                205.78                30.63
# 30                983.97                55.47
# 39               1234.63                65.69
# ...

# %%
gfw_2024 = gfw[gfw.Year == 2024]
gfw_2024.head()
# Out:
#          Country  Year        Food Category  Total Waste (Tons)  \
# 5          India  2024  Fruits & Vegetables            11962.89
# 6        Germany  2024        Prepared Food            45038.72
# 10  South Africa  2024          Frozen Food            39478.70
# 12           USA  2024            Beverages            22924.85
# 24  Saudi Arabia  2024        Prepared Food            33085.77
#
#     Economic Loss (Million $)  Avg Waste per Capita (Kg)  \
# 5                    11196.04                     136.21
# 6                    39191.25                     179.27
# 10                   40087.26                     155.55
# 12                   22406.24                      89.59
# 24                   28923.13                      37.71
#
#     Population (Million)  Household Waste (%)
# 5                1311.91                37.09
# 6                1349.45                68.93
# 10                375.84                31.16
# 12                836.05                45.43
# ...

# %%
gfw_2018[['Country','Year', 'Food Category','Population (Million)']].head()
# Out:
#     Country  Year   Food Category  Population (Million)
# 13   France  2018       Beverages               1286.73
# 19    China  2018   Prepared Food                953.52
# 25  Germany  2018       Beverages                689.21
# 27   France  2018     Frozen Food                855.40
# 29   Mexico  2018  Meat & Seafood                412.45

# %%
gfw_2018['Food Category'].value_counts()
# Out:
# Food Category
# Beverages              100
# Bakery Items            98
# Prepared Food           97
# Frozen Food             87
# Dairy Products          87
# Meat & Seafood          84
# Grains & Cereals        82
# Fruits & Vegetables     73
# Name: count, dtype: int64

# %%
gfw_2020[['Country','Year', 'Food Category','Population (Million)']].head()
# Out:
#          Country  Year        Food Category  Population (Million)
# 17  Saudi Arabia  2020        Prepared Food                143.12
# 21     Australia  2020  Fruits & Vegetables                205.78
# 30     Argentina  2020         Bakery Items                983.97
# 39         Japan  2020            Beverages               1234.63
# 41        Russia  2020       Dairy Products                776.16

# %%
gfw_2020['Food Category'].value_counts()
# Out:
# Food Category
# Prepared Food          100
# Beverages               98
# Meat & Seafood          97
# Fruits & Vegetables     90
# Bakery Items            90
# Dairy Products          88
# Frozen Food             87
# Grains & Cereals        81
# Name: count, dtype: int64

# %%
gfw_2024[['Country','Year', 'Food Category','Population (Million)']].head()
# Out:
#          Country  Year        Food Category  Population (Million)
# 5          India  2024  Fruits & Vegetables               1311.91
# 6        Germany  2024        Prepared Food               1349.45
# 10  South Africa  2024          Frozen Food                375.84
# 12           USA  2024            Beverages                836.05
# 24  Saudi Arabia  2024        Prepared Food                552.45

# %%
gfw_2024['Food Category'].value_counts()
# Out:
# Food Category
# Prepared Food          105
# Fruits & Vegetables    101
# Frozen Food             94
# Dairy Products          92
# Grains & Cereals        86
# Meat & Seafood          86
# Bakery Items            84
# Beverages               73
# Name: count, dtype: int64

# %%
selected_years = [2018, 2020, 2024]
gfw_filtered = gfw[gfw["Year"].isin(selected_years)]

# %%
plt.figure(figsize=(12, 6))
sns.countplot(
    data=gfw_filtered, 
    x="Food Category", 
    hue="Year",  # Different colors for each year
    palette="Set2"  # Color theme
)

plt.xlabel("Food Category")
plt.ylabel("Count")
plt.title("Food Category Distribution for 2018, 2020, and 2024")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title="Year")

# Show the plot
plt.show()

# %% [raw]
# Fruits & Vegetables: The count increased significantly over the years. (2018 Lowest / 2024 Highest)
# Prepared Food: An increasing is observed
# Frozen Food: The count remained relatively stable, with a slight increase in 2024.
# Beverages: The count in 2018 was high but dropped in 2024 after an increase in 2020. (fluctuating consumer preferences)
# Meat & Seafood: There was a rise from 2018 to 2020, but a slight decrease in 2024. (This could be related to changing dietary habits, health concerns, or market trends such as increased plant-based diets.)
# Bakery Items: The count decreased over time, with 2024 being lower than 2018 and 2020. (might be due to a shift in dietary preferences, possibly toward healthier or low-carb options.)
# Grains & Cereals: A slight increase in 2024 after a small dip in 2020.
# Dairy Products: A slightly increasing through years.

# %% [markdown]
# #### 6 ) Which countries generate the highest per capita food waste?

# %%
## will use the country and Avg waste per capita to show the impact of each person in the food wasting
Country_avg_waste = gfw.groupby('Country')['Avg Waste per Capita (Kg)'].sum().sort_values(ascending = False)
Country_avg_waste
# Out:
# Country
# Germany         33213.70
# China           29098.11
# USA             28725.29
# Italy           28384.67
# Spain           28351.28
# Canada          28021.47
# India           27991.09
# Brazil          27797.14
# Mexico          27676.09
# Saudi Arabia    27366.26
# South Korea     27266.55
# Turkey          27110.32
# France          26754.31
# Russia          26445.61
# South Africa    26354.48
# Japan           26254.85
# Argentina       26133.63
# Indonesia       25579.72
# Australia       24510.88
# UK              24284.40
# Name: Avg Waste per Capita (Kg), dtype: float64

# %%
top_count = Country_avg_waste[:10]
top_count
# Out:
# Country
# Germany         33213.70
# China           29098.11
# USA             28725.29
# Italy           28384.67
# Spain           28351.28
# Canada          28021.47
# India           27991.09
# Brazil          27797.14
# Mexico          27676.09
# Saudi Arabia    27366.26
# Name: Avg Waste per Capita (Kg), dtype: float64

# %%
colors = sns.color_palette("tab10",len(top_count))
plt.pie(top_count , labels = top_count.index, autopct='%1.1f%%', colors = colors,startangle=140 )
plt.title("Top 10 Countries with great average of waste per capita")
# Out:
# Text(0.5, 1.0, 'Top 10 Countries with great average of waste per capita')

# %% [raw]
# Here we can see that Highest Country with Food wastes through years from 2018 - 2024 is "Turkey" and "Canada" and the least in food wastes are "South Korea" and "UK"

# %% [markdown]
# #### 7 ) Are high-income nations wasting more food per capita than low-income ones?

# %%
gfw.head()
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 0  Australia  2019  Fruits & Vegetables            19268.63
# 1  Indonesia  2019        Prepared Food             3916.97
# 2    Germany  2022       Dairy Products             9700.16
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
#
#    Economic Loss (Million $)  Avg Waste per Capita (Kg)  Population (Million)  \
# 0                   18686.68                      72.69                 87.59
# 1                    4394.48                     192.52               1153.99
# 2                    8909.16                     166.94               1006.11
# 3                   40551.22                     120.19                953.05
# 4                   36980.82                     104.74               1105.47
#
#    Household Waste (%)
# 0                53.64
# 1                30.61
# 2                48.08
# 3                31.91
# ...

# %%
gfw['Country'].value_counts()
# Out:
# Country
# Germany         287
# Spain           274
# China           262
# Brazil          258
# USA             257
# India           257
# Turkey          256
# Canada          254
# Italy           253
# Mexico          251
# South Africa    245
# Indonesia       244
# UK              242
# South Korea     241
# Japan           240
# Saudi Arabia    239
# France          239
# Argentina       238
# Russia          237
# Australia       226
# Name: count, dtype: int64

# %%
country_gdp = {
    "USA": 25462700,
    "China": 19374000,
    "Japan": 4230000,
    "Germany": 4072200,
    "India": 3385100,
    "UK": 3070000,
    "France": 2782000,
    "Italy": 2107000,
    "Canada": 2089000,
    "South Korea": 1755000,
    "Russia": 1483000,
    "Brazil": 1445000,
    "Australia": 1376000,
    "Spain": 1358000,
    "Mexico": 1274000,
    "Indonesia": 1186000,
    "Netherlands": 1045000,
    "Saudi Arabia": 1042000,
    "Turkey": 942000,
    "Switzerland": 824000 
}

# %%
gfw['CountryGDP (in Millions)'] = gfw['Country'].map(country_gdp)

# %%
gfw.head()
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 0  Australia  2019  Fruits & Vegetables            19268.63
# 1  Indonesia  2019        Prepared Food             3916.97
# 2    Germany  2022       Dairy Products             9700.16
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
#
#    Economic Loss (Million $)  Avg Waste per Capita (Kg)  Population (Million)  \
# 0                   18686.68                      72.69                 87.59
# 1                    4394.48                     192.52               1153.99
# 2                    8909.16                     166.94               1006.11
# 3                   40551.22                     120.19                953.05
# 4                   36980.82                     104.74               1105.47
#
#    Household Waste (%)  CountryGDP (in Millions)
# 0                53.64                 1376000.0
# ...

# %%
gfw_gdp = gfw.groupby("Country").agg({'CountryGDP (in Millions)':'first', 'Avg Waste per Capita (Kg)' : "mean"})

# %%
gfw_gdp
# Out:
#               CountryGDP (in Millions)  Avg Waste per Capita (Kg)
# Country
# Argentina                          NaN                 109.805168
# Australia                    1376000.0                 108.455221
# Brazil                       1445000.0                 107.740853
# Canada                       2089000.0                 110.320748
# China                       19374000.0                 111.061489
# France                       2782000.0                 111.942720
# Germany                      4072200.0                 115.727178
# India                        3385100.0                 108.914747
# Indonesia                    1186000.0                 104.834918
# Italy                        2107000.0                 112.192372
# Japan                        4230000.0                 109.395208
# Mexico                       1274000.0                 110.263307
# Russia                       1483000.0                 111.584852
# ...

# %%
sns.scatterplot(
    data=gfw_gdp, 
    x="CountryGDP (in Millions)", 
    y="Avg Waste per Capita (Kg)", 
    hue="Avg Waste per Capita (Kg)",  # Hue based on per capita waste
    palette="coolwarm",  # Color gradient (you can try "viridis", "plasma", etc.)
    size="Avg Waste per Capita (Kg)",  # Adjust point size based on waste level
    sizes=(20, 200),  # Scale sizes
    edgecolor="black"
)
plt.xlabel("Country GDP (Million $)")
plt.ylabel("Average Waste per Capita (Kg)")
plt.title("Food Waste Per Capita vs. GDP")

plt.legend(title="Waste per Capita", bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [raw]
# The largest bubbles (high waste per capita) are concentrated at the lower end of the GDP scale, implying that some lower GDP countries still experience high food waste.

# %%
gfw[['CountryGDP (in Millions)','Avg Waste per Capita (Kg)']].corr()
# Out:
#                            CountryGDP (in Millions)  Avg Waste per Capita (Kg)
# CountryGDP (in Millions)                   1.000000                   0.015133
# Avg Waste per Capita (Kg)                  0.015133                   1.000000

# %% [markdown]
# #### 8 ) Check if a country's food waste per capita is influenced by its population size (2024)

# %%
gfw.head()
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 0  Australia  2019  Fruits & Vegetables            19268.63
# 1  Indonesia  2019        Prepared Food             3916.97
# 2    Germany  2022       Dairy Products             9700.16
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
#
#    Economic Loss (Million $)  Avg Waste per Capita (Kg)  Population (Million)  \
# 0                   18686.68                      72.69                 87.59
# 1                    4394.48                     192.52               1153.99
# 2                    8909.16                     166.94               1006.11
# 3                   40551.22                     120.19                953.05
# 4                   36980.82                     104.74               1105.47
#
#    Household Waste (%)  CountryGDP (in Millions)
# 0                53.64                 1376000.0
# ...

# %%
gfw_2024_pop = gfw[gfw['Year'] == 2024]
gfw_2024_pop.head()

gfw_2024_pop.groupby("Country").agg({'Population (Million)':'first', 'Avg Waste per Capita (Kg)' : "mean"})
# Out:
#               Population (Million)  Avg Waste per Capita (Kg)
# Country
# Argentina                   790.96                 109.628065
# Australia                    88.75                 118.816207
# Brazil                      513.73                  98.762286
# Canada                     1327.02                 106.660541
# China                        84.69                 110.195946
# France                     1082.83                  99.601818
# Germany                    1349.45                 115.956316
# India                      1311.91                 121.373750
# Indonesia                   891.66                 102.984118
# Italy                       467.60                 112.422821
# Japan                      1303.51                 118.338621
# Mexico                      868.78                 103.687857
# Russia                     1322.56                 118.012703
# Saudi Arabia                552.45                 127.274000
# ...

# %%
plt.figure(figsize = (10,6))
sns.histplot(data = gfw_2024_pop ,x ='Population (Million)', y = 'Avg Waste per Capita (Kg)' , hue = 'Country' ,palette= 'viridis' )
plt.xlabel('Population (Millions)')
plt.ylabel('Average Waste per capita (Kg)')
plt.title('Population vs Average waste per capita based on Countries')
# Out:
# Text(0.5, 1.0, 'Population vs Average waste per capita based on Countries')

# %% [raw]
# The data is spread across different population sizes, but there is no clear trend linking higher population to higher waste per capita. Some lower population countries have similar waste levels to highly populated ones. This suggests population size alone does not dictate food waste per capita, meaning factors like economy, culture, and consumption habits likely play a role.

# %%
gfw_2024_pop.groupby("Country").agg({'CountryGDP (in Millions)':'first', 'Avg Waste per Capita (Kg)' : "mean"})
# Out:
#               CountryGDP (in Millions)  Avg Waste per Capita (Kg)
# Country
# Argentina                          NaN                 109.628065
# Australia                    1376000.0                 118.816207
# Brazil                       1445000.0                  98.762286
# Canada                       2089000.0                 106.660541
# China                       19374000.0                 110.195946
# France                       2782000.0                  99.601818
# Germany                      4072200.0                 115.956316
# India                        3385100.0                 121.373750
# Indonesia                    1186000.0                 102.984118
# Italy                        2107000.0                 112.422821
# Japan                        4230000.0                 118.338621
# Mexico                       1274000.0                 103.687857
# Russia                       1483000.0                 118.012703
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=gfw_2024_pop, x="CountryGDP (in Millions)", y="Avg Waste per Capita (Kg)", hue="Household Waste (%)", palette="viridis")
plt.title("Is Food Waste Per Capita Higher in Wealthy Countries?")
plt.xlabel("Country GDP")
plt.ylabel("Avg Waste per Capita (Kg)")
plt.show()

# %% [raw]
# The data points seem highly concentrated on the lower GDP side, meaning most countries in the dataset have relatively lower GDP. higher GDP countries (towards the right) still show varied food waste per capita levels.
# There's no clear trend, but a slight indication that Higher GDP countries may have a higher average waste per capita, though variability exists.

# %% [markdown]
# #### 9 ) Based on historical data, which regions are projected to have the highest food waste in the coming years?

# %%
country_region = {
    "USA": 'North America',
    "China": 'Asia',
    "Japan": 'Asia',
    "Germany": 'Europe',
    "India": 'Asia',
    "UK": 'Europe',
    "France": 'Europe',
    "Italy": 'Europe',
    "South Africa": 'AFC',
    "Canada": 'North America',
    "South Korea": 'Asia',
    "Russia": 'Asia',
    "Argentina":"South America",
    "Brazil": 'South America',
    "Australia": 'Ocean',
    "Spain": 'Europe',
    "Mexico": 'North America',
    "Indonesia": 'Asia',
    "Netherlands": 'Europe',
    "Saudi Arabia": 'Asia',
    "Turkey": 'Asia',
    "Switzerland": 'Europe' 
}

# %%
gfw['Country_Region'] = gfw['Country'].map(country_region)
gfw.head()
# Out:
#      Country  Year        Food Category  Total Waste (Tons)  \
# 0  Australia  2019  Fruits & Vegetables            19268.63
# 1  Indonesia  2019        Prepared Food             3916.97
# 2    Germany  2022       Dairy Products             9700.16
# 3     France  2023  Fruits & Vegetables            46299.69
# 4     France  2023            Beverages            33096.57
#
#    Economic Loss (Million $)  Avg Waste per Capita (Kg)  Population (Million)  \
# 0                   18686.68                      72.69                 87.59
# 1                    4394.48                     192.52               1153.99
# 2                    8909.16                     166.94               1006.11
# 3                   40551.22                     120.19                953.05
# 4                   36980.82                     104.74               1105.47
#
#    Household Waste (%)  CountryGDP (in Millions) Country_Region
# 0                53.64                 1376000.0          Ocean
# ...

# %%
selected_years = [2018, 2020, 2024]
gfw_filtered = gfw[gfw["Year"].isin(selected_years)]

# %%
# Reset index to convert into a DataFrame
cr = gfw_filtered.groupby('Country_Region')['Country'].value_counts().reset_index(name='Count')

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=cr, x='Country_Region', y='Count', hue='Country', dodge=False)

# Formatting
plt.title("Number of Countries per Region")
plt.xlabel("Region")
plt.ylabel("Number of Countries")
plt.legend(title="Countries", bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %%
# Group by 'Country_Region' and sum up 'Total Waste (Tons)'
region_waste = gfw_filtered.groupby('Country_Region')['Total Waste (Tons)'].sum().reset_index()

# Sort for better visualization
region_waste = region_waste.sort_values(by='Total Waste (Tons)', ascending=False)

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=region_waste, x='Country_Region', y='Total Waste (Tons)', palette="viridis")

# Formatting
plt.xticks(rotation=45, ha='right')
plt.title("Total Food Waste (Tons) by Region")
plt.xlabel("Region")
plt.ylabel("Total Waste (Tons)")

plt.show()
# Out:
# <ipython-input-54-fcf4af76f171>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=region_waste, x='Country_Region', y='Total Waste (Tons)', palette="viridis")

# %% [raw]
# Asia:  has the highest food waste, exceeding 21 million tons, significantly more than any other region.
# Europe: follows with around 13-14 million tons, indicating a considerable food waste issue.
# South America: contributes approximately 5-6 million tons, showing a decline in food waste compared to the previous regions.
# Africa and Oceania: have the lowest food waste, with values below 3 million tons, indicating less waste per region.
